# %% [markdown]
# ## Starting Off
#
# Message me one question you have about APIs. Any question at all

# %% [markdown]
# # Using APIs and JSON Data

# %% [markdown]
# ## Objectives
# You will be able to:
# * Make an API call to Yelp

# %% [markdown]
# ## Agenda
#
# * Build up an API Call
# * Look at the results

# %%
import requests
import json

# %% [markdown]
# For more information about the request package you can use the following resources:
#
# **Tutorial:** https://realpython.com/python-requests/
#
# **Package Documentation:** https://requests.readthedocs.io/en/master/

# %% [markdown]
# ![](quota.png)

# %% [markdown]
# Let's do a search of businesses on the Yelp API.

# %%
# set theurl and endpoint we want to hit
url =  'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# Now that you have an API key, let's enter set that information here so that we can do our searches. Once you have the `api_key` variable, place int in our header.

# %%
client_id = 'M3mNq5Ck5s1JoAhGyL5EQg'
api_key = '_jkFIV5zFMaQvSW-TwZgOnhFbm6Q6jEgW2Lni1eY5Cln3l2fJ31bnlJJz0BhFciNsJ3yJgcC9DJcp7em8coJY2T9KeEfUtKFb0ddhwPCgpjmwwdZc0WuZMW_pr6PXnYx'

# %% [markdown]
# from  keys  import  client_id, api_key

# %% [markdown]
# print(api_key)

# %%
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %% [markdown]
# We now need to determine our parameters we want to pass.
#
# You must give a specific search term, location and one other paramter to limit your search.
#
# Remember you can search the API documenation to find another parameter to limit your search.
# https://www.yelp.com/developers/documentation/v3/get_started

# %%
# what type of business do you want to search
term = 'Chinese Takeout'

#where do you want to perform this search
location = 'Brooklyn Heights NY'

# what is your other parameter you want to search against
open_now = True

# %%
url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "open_now" : True,
                "limit": 50
            }

# %%
url_params
# Out:
# {'term': 'Chinese+Takeout',
#  'location': 'Brooklyn+Heights+NY',
#  'open_now': True,
#  'limit': 50}

# %% [markdown]
# Now that we have all of the parts necessary for an API call, let's put them together.

# %%
response = requests.get(url, headers=headers, params=url_params)

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ## The Response
#
# The response of a GET request often has some valuable information, known as a payload, in the message body. Using the attributes and methods of Response, you can view the payload in a variety of different formats.
#
# To see the response’s content in bytes, you use `.content`
#
# You will often want to convert them into a string using a character encoding such as UTF-8. Response will do that for you when you access `.text`
#
# The response is actually serialized JSON content. To get a dictionary, you could take the str you retrieved from `.text` and deserialize it using `json.loads()`. However, a simpler way to accomplish this task is to use `.json()`:

# %%
response.text
# Out:
# '{"businesses": [{"id": "rPTX2J5KGDkN1QhPD-QOvg", "alias": "xifu-food-brooklyn", "name": "Xifu Food", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/SiWrJqq1wyIbUWFbhjgoXQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/xifu-food-brooklyn?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg", "review_count": 139, "categories": [{"alias": "chinese", "title": "Chinese"}], "rating": 4.5, "coordinates": {"latitude": 40.6880326, "longitude": -73.9819963}, "transactions": [], "price": "$", "location": {"address1": "318 Livingston St", "address2": "", "address3": null, "city": "Brooklyn", "zip_code": "11217", "country": "US", "state": "NY", "display_address": ["318 Livingston St", "Brooklyn, NY 11217"]}, "phone": "+17182378886", "display_phone": "(718) 237-8886", "distance": 1356.6514866975099}, {"id": "5u4T6-Z-KhHrRZ9g54pugQ", "alias": "carols-bun-new-york-3", "name": "Carol\'s Bun", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/d8qaSRuicMeA-HCl7MzoqQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/carols-bun-new-york-3?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg", "review_count": 32, "categories": [{"alias": "chinese", "title": "Chinese"}], "rating": 4.0, "coordinates": {"latitude": 40.7138317002555, "longitude": -73.9914554524045}, "transactions": [], "price": "$", "location": {"address1": "139 E Broadway", "address2": "", "address3": "", "city": "New York", "zip_code": "10002", "country": "US", "state": "NY", "display_address": ["139 E Broadway", "New York, NY 10002"]}, "phone": "+12125660203", "display_phone": "(212) 566-0203", "distance": 2019.9457609230337}, {"id": "nrPfcOC4mGnEL-9CpoGhMg", "alias": "mings-caffe-new-york-2", "name": "Ming\'s Caffe", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/vgCU2O31el1_g1bEKxgmLA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/mings-caffe-new-york-2?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg", "review_count": 118, "categories": [{"alias": "chinese", "title": "Chinese"}, {"alias": "hkcafe", "title": "Hong Kong Style Cafe"}], "rating": 4.0, "coordinates": {"latitude": 40.714321, "longitude": -73.990509}, "transactions": [], "price": "$", "location": {"address1": "28 Canal St", "address2": "", "address3": "", "city": "New York", "zip_code": "10002", "country": "US", "state": "NY", "display_address": ["28 Canal St", "New York, NY 10002"]}, "phone": "+12129781888", "display_phone": "(212) 978-1888", "distance": 2086.7795942083126}, {"id": "__r8_g1cgDaiDn10cGeJ3Q", "alias": "new-china-red-new-york", "name": "New China Red", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/gsfiiwySR5mWnxx70KA0PQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/new-china-red-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg", "review_count": 33, "categories": [{"alias": "chinese", "title": "Chinese"}], "rating": 2.5, "coordinates": {"latitude": 40.715023, "longitude": -74.008636}, "transactions": ["pickup", "delivery"], "price": "$", "location": {"address1": "118 Chambers St", "address2": "", "address3": "", "city": "New York", "zip_code": "10007", "country": "US", "state": "NY", "display_address": ["118 Chambers St", "New York, NY 10007"]}, "phone": "+12122674015", "display_phone": "(212) 267-4015", "distance": 2452.3155188530686}, {"id": "Mx4jHwGh5ZFHRMyiWZ_xfw", "alias": "happy-express-cafe-new-york-3", "name": "Happy Express Cafe", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/TRFxa78dawOYkIIwJ2useg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/happy-express-cafe-new-york-3?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search ...

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': 'rPTX2J5KGDkN1QhPD-QOvg',
#    'alias': 'xifu-food-brooklyn',
#    'name': 'Xifu Food',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SiWrJqq1wyIbUWFbhjgoXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xifu-food-brooklyn?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 139,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6880326, 'longitude': -73.9819963},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '318 Livingston St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['318 Livingston St', 'Brooklyn, NY 11217']},
#    'phone': '+17182378886',
#    'display_phone': '(718) 237-8886',
#    'distance': 1356.6514866975099},
#   {'id': '5u4T6-Z-KhHrRZ9g54pugQ',
#    'alias': 'carols-bun-new-york-3',
#    'name': "Carol's Bun",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/d8qaSRuicMeA-HCl7MzoqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carols-bun-new-york-3?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 32,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7138317002555,
#     'longitude': -73.9914554524045},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '139 E Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 E Broadway', 'New York, NY 10002']},
#    'phone': '+12125660203',
#    'display_phone': '(212) 566-0203',
#    'distance': 2019.9457609230337},
#   {'id': 'nrPfcOC4mGnEL-9CpoGhMg',
#    'alias': 'mings-caffe-new-york-2',
#    'name': "Ming's Caffe",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vgCU2O31el1_g1bEKxgmLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mings-caffe-new-york-2?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 118,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714321, 'longitude': -73.990509},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '28 Canal St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 Canal St', 'New York, NY 10002']},
#    'phone': '+12129781888',
#    'display_phone': '(212) 978-1888',
#    'distance': 2086.7795942083126},
#   {'id': '__r8_g1cgDaiDn10cGeJ3Q',
#    'alias': 'new-china-red-new-york',
#    'name': 'New China Red',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gsfiiwySR5mWnxx70KA0PQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-china-red-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 33,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.715023, 'longitude': -74.008636},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '118 Chambers St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['118 Chambers St', 'New York, NY 10007']},
#    'phone': '+12122674015',
#    'display_phone': '(212) 267-4015',
#    'distance': 2452.3155188530686},
#   {'id': 'Mx4jHwGh5ZFHRMyiWZ_xfw',
#    'alias': 'happy-express-cafe-new-york-3',
#    'name': 'Happy Express Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TRFxa78dawOYkIIwJ2useg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/happy-express-cafe-new-york-3?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 41,
#    'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7145133, 'longitude': -73.9924451},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '6 Allen St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6 Allen St', 'New York, NY 10002']},
#    'phone': '+12129659898',
#    'display_phone': '(212) 965-9898',
#    'distance': 2099.6082718994458},
#   {'id': 'pmE7JG661llrNWu9IA5Y_Q',
#    'alias': 'tan-wong-restaurant-new-york',
#    'name': 'Tan Wong Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/W9crxVMi9onR-VBrIqo92A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tan-wong-restaurant-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 8,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7136, 'longitude': -73.99317},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '103 E Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 E Broadway', 'New York, NY 10002']},
#    'phone': '+12123856015',
#    'display_phone': '(212) 385-6015',
#    'distance': 1979.27005678312},
#   {'id': 'bT4CDzyhV-frXV6ijvXnvw',
#    'alias': 'super-taste-new-york',
#    'name': 'Super Taste',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Y-rfOV4CDxtWPkV_d2JWcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/super-taste-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 551,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71513, 'longitude': -73.99341},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '26 Eldridge St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 Eldridge St', 'New York, NY 10002']},
#    'phone': '+16462830999',
#    'display_phone': '(646) 283-0999',
#    'distance': 2144.1588420993007},
#   {'id': '2IrDzLVFUFPp229c1x8YNw',
#    'alias': 'hong-man-new-york',
#    'name': 'Hong Man',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UsSOZuq4qGImJqudMtge2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hong-man-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 137,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.715145, 'longitude': -73.993698},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '27 Eldridge St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27 Eldridge St', 'New York, NY 10002']},
#    'phone': '+12129250805',
#    'display_phone': '(212) 925-0805',
#    'distance': 2153.324285475651},
#   {'id': 'd_TC6Om2EBTzHVm_lCgNtg',
#    'alias': 'great-ny-noodle-town-new-york',
#    'name': 'Great NY Noodle Town',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BAzE7G6WNiUqJqLTRPYSvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/great-ny-noodle-town-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 1319,
#    'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7150363828814,
#     'longitude': -73.9971172437072},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '28 Bowery',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 Bowery', 'New York, NY 10013']},
#    'phone': '+12123490923',
#    'display_phone': '(212) 349-0923',
#    'distance': 2151.2285085230733},
#   {'id': 'GfLL6-n6UNZ07SEHfjeIgA',
#    'alias': 'mee-sum-cafe-new-york',
#    'name': 'Mee Sum Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/N4Yc3eeDHXeePQWkeyBnyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mee-sum-cafe-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 33,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.715045, 'longitude': -73.998291},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '26 Pell St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 Pell St', 'New York, NY 10013']},
#    'phone': '+12123495260',
#    'display_phone': '(212) 349-5260',
#    'distance': 2165.8030537026007},
#   {'id': 'lRSiXYB09Z5x1iINqQ7rHA',
#    'alias': 'dim-sum-go-go-new-york',
#    'name': 'Dim Sum Go Go',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Gxye_bydWtbWabHxVDQ5gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dim-sum-go-go-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 781,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7132415735622,
#     'longitude': -73.9977319419107},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '5 E Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 E Broadway', 'New York, NY 10038']},
#    'phone': '+12127320797',
#    'display_phone': '(212) 732-0797',
#    'distance': 1959.724552602302},
#   {'id': 'Y1s36Tk63HIzAc76X_fAiQ',
#    'alias': 'hop-shing-restaurant-new-york',
#    'name': 'Hop Shing Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cYzq0hhv8ruMQ9HinOEVzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hop-shing-restaurant-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 533,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71418, 'longitude': -73.99811},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '9 Chatham Sq',
#     'address2': 'Ste 1',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Chatham Sq', 'Ste 1', 'New York, NY 10038']},
#    'phone': '+12122670220',
#    'display_phone': '(212) 267-0220',
#    'distance': 2043.708843448393},
#   {'id': 'VaL9GaBR_GR-q9d1VzJF3g',
#    'alias': 'suteishi-new-york',
#    'name': 'Suteishi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4BbRNhy7IJz7PL1sJDmAlg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/suteishi-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 490,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70788, 'longitude': -74.00194},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '24 Peck Slip',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 Peck Slip', 'New York, NY 10038']},
#    'phone': '+12127662344',
#    'display_phone': '(212) 766-2344',
#    'distance': 1487.0761321951231},
#   {'id': 'wctR1TrheHAwpHZ2sJknEw',
#    'alias': 'yemen-cafe-and-restaurant-brooklyn-3',
#    'name': 'Yemen Cafe & Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/naw33McdBGb70-6qc5go4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yemen-cafe-and-restaurant-brooklyn-3?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 510,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6899167976363,
#     'longitude': -73.9936561765076},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '176 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['176 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17188349533',
#    'display_phone': '(718) 834-9533',
#    'distance': 657.1890288804198},
#   {'id': 'HFOiW4RvijuoblE4DD3JwA',
#    'alias': 'dekalb-market-hall-brooklyn-2',
#    'name': 'Dekalb Market Hall',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p3HJcEcHV7KuX0XVh30KUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dekalb-market-hall-brooklyn-2?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 665,
#    'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.691025, 'longitude': -73.983311},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '445 Albee Square W',
#     'address2': 'Basement Level',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['445 Albee Square W',
#      'Basement Level',
#      'Brooklyn, NY 11201']},
#    'phone': '+19293596555',
#    'display_phone': '(929) 359-6555',
#    'distance': 1073.7041848440692},
#   {'id': 'rkeH5HJIuX7ZcOaYNum9xA',
#    'alias': 'wus-wonton-king-new-york',
#    'name': "Wu's Wonton King",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QjIkktkArC8ZLduMobSAzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wus-wonton-king-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 265,
#    'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7139415501646,
#     'longitude': -73.9899386554248},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '165 E Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['165 E Broadway', 'New York, NY 10002']},
#    'phone': '+12124771111',
#    'display_phone': '(212) 477-1111',
#    'distance': 2051.5053402356925},
#   {'id': 'Cd11Q5nxqthvg5xQx2SW2g',
#    'alias': 'tasty-dumpling-new-york',
#    'name': 'Tasty Dumpling',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/l6Rh7VbXaavoXZ2z4Xr0CQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tasty-dumpling-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 500,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7149408310765,
#     'longitude': -73.9995409548283},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '42 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 Mulberry St', 'New York, NY 10013']},
#    'phone': '+12123490070',
#    'display_phone': '(212) 349-0070',
#    'distance': 2172.2108661811985},
#   {'id': 'ZyQfNryF0YBdzGnzLoVsWQ',
#    'alias': 'j-j-noodle-restaurant-new-york',
#    'name': 'J.J. Noodle Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/10oc8taJq51elsEX_HURjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/j-j-noodle-restaurant-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 45,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7128724455833,
#     'longitude': -73.9968185126781},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '19 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Henry St', 'New York, NY 10002']},
#    'phone': '+12125712440',
#    'display_phone': '(212) 571-2440',
#    'distance': 1905.5049326686446},
#   {'id': '_5E5cZP0PzkwfdEqTebBUg',
#    'alias': 'lanzhou-ramen-new-york-3',
#    'name': 'Lanzhou Ramen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IpPighKcuYrTyeoFl6jKFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lanzhou-ramen-new-york-3?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 57,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7136041, 'longitude': -73.9930138},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '107 E Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['107 E Broadway', 'New York, NY 10038']},
#    'phone': '+16469983175',
#    'display_phone': '(646) 998-3175',
#    'distance': 1982.8902576294413},
#   {'id': 'bNO0801dOoSSFJuDdTDzYQ',
#    'alias': 'hadramout-restaurant-brooklyn',
#    'name': 'Hadramout Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BU1YCbgdFtGe2XggJMK3kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hadramout-restaurant-brooklyn?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 80,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6898184, 'longitude': -73.9938774},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '172 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['172 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17182221066',
#    'display_phone': '(718) 222-1066',
#    'distance': 666.6413242254652},
#   {'id': '02zyTkuXvbGcbA9en_20Gw',
#    'alias': 'chatham-seafood-restaurant-new-york-3',
#    'name': 'Chatham Seafood Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9vyr6zN3TkiZgnOeye7XhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chatham-seafood-restaurant-new-york-3?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 199,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7139257701126,
#     'longitude': -73.9982688968362},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '6 Chatham Sq',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6 Chatham Sq', 'New York, NY 10038']},
#    'phone': '+12122338877',
#    'display_phone': '(212) 233-8877',
#    'distance': 2041.8158664868913},
#   {'id': 'cn3JXMq29UfRkFCUD0Bhbw',
#    'alias': 'fried-dumpling-new-york',
#    'name': 'Fried Dumpling',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bHZRArfOJlXzwRtky_Fn_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fried-dumpling-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 518,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7145984, 'longitude': -73.9993465},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '106 Mosco St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['106 Mosco St', 'New York, NY 10013']},
#    'phone': '+12126931060',
#    'display_phone': '(212) 693-1060',
#    'distance': 2127.405749442871},
#   {'id': 'NL7yHrgnOVNtKNRPon5vGQ',
#    'alias': 'delight-28-restaurant-new-york-2',
#    'name': 'Delight 28 Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KXhoDiZyz2-GbzBzVD2NMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/delight-28-restaurant-new-york-2?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 162,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.715089, 'longitude': -73.998459},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '28 Pell St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 Pell St', 'New York, NY 10013']},
#    'phone': '+12122858686',
#    'display_phone': '(212) 285-8686',
#    'distance': 2172.060818671315},
#   {'id': 'aoYDuvipcT_XGAM5ckFJnA',
#    'alias': 'cafe-water-new-york',
#    'name': 'Cafe Water',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YfwkAImpiK3ClwXhZgbn-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-water-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 86,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7056344, 'longitude': -74.0068667},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '130 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['130 Water St', 'New York, NY 10005']},
#    'phone': '+12127851320',
#    'display_phone': '(212) 785-1320',
#    'distance': 1517.7687908353644},
#   {'id': '7YxyC11C6gTKGg2qoiF4XQ',
#    'alias': 'banh-mi-cart-new-york',
#    'name': 'Banh Mi Cart',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T9hX8NRQa68Gupz4CrnXUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/banh-mi-cart-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 123,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70455, 'longitude': -74.0094699},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': 'Pearl St & Hanover Sq',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Pearl St & Hanover Sq', 'New York, NY 10038']},
#    'phone': '+19174957071',
#    'display_phone': '(917) 495-7071',
#    'distance': 1602.5262183452712},
#   {'id': '-qO9s7w4krZ_Wfziqzn7Hw',
#    'alias': 'adels-halal-food-new-york-2',
#    'name': "Adel's Halal Food",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F1TKk-94tFi7g3BnUGiGBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/adels-halal-food-new-york-2?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 75,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70578, 'longitude': -74.00554},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': 'Maiden Ln & Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Maiden Ln & Front St', 'New York, NY 10038']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1452.8566219302647},
#   {'id': 'GlPJPpKvPR4d8dmcSEYpdA',
#    'alias': 'takahachi-bakery-new-york',
#    'name': 'Takahachi Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aoi0dkVvxooH8ZCFUC3lSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/takahachi-bakery-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 899,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71393, 'longitude': -74.00822},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '25 Murray St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Murray St', 'New York, NY 10007']},
#    'phone': '+12127915550',
#    'display_phone': '(212) 791-5550',
#    'distance': 2333.1659440405356},
#   {'id': 'brs8l_uwP8lKNzvbJD5kiA',
#    'alias': 'cafe-exchange-new-york',
#    'name': 'Cafe Exchange',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QrcqGznOWd6_tMPeAV57Ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-exchange-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 81,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.70673, 'longitude': -74.01312},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '49 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10006',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['49 Broadway', 'New York, NY 10006']},
#    'phone': '+12124255000',
#    'display_phone': '(212) 425-5000',
#    'distance': 2012.9357279020985},
#   {'id': 'tAHRDrCR0l_utA91IyOYNw',
#    'alias': 'baba-ghanouge-new-york',
#    'name': 'Baba Ghanouge',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Wv-zUukAA_vHJ7vgVSkY3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baba-ghanouge-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 151,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.71511, 'longitude': -74.00758},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '165 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['165 Church St', 'New York, NY 10007']},
#    'phone': '+12125712020',
#    'display_phone': '(212) 571-2020',
#    'distance': 2414.1235615722085}],
#  'total': 30,
#  'region': {'center': {'longitude': -73.9943790435791,
#    'latitude': 40.69580157862677}}}

# %%
response.json()
# Out:
# {'businesses': [{'id': 'rPTX2J5KGDkN1QhPD-QOvg',
#    'alias': 'xifu-food-brooklyn',
#    'name': 'Xifu Food',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SiWrJqq1wyIbUWFbhjgoXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xifu-food-brooklyn?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 139,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6880326, 'longitude': -73.9819963},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '318 Livingston St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['318 Livingston St', 'Brooklyn, NY 11217']},
#    'phone': '+17182378886',
#    'display_phone': '(718) 237-8886',
#    'distance': 1356.6514866975099},
#   {'id': '5u4T6-Z-KhHrRZ9g54pugQ',
#    'alias': 'carols-bun-new-york-3',
#    'name': "Carol's Bun",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/d8qaSRuicMeA-HCl7MzoqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carols-bun-new-york-3?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 32,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7138317002555,
#     'longitude': -73.9914554524045},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '139 E Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 E Broadway', 'New York, NY 10002']},
#    'phone': '+12125660203',
#    'display_phone': '(212) 566-0203',
#    'distance': 2019.9457609230337},
#   {'id': 'nrPfcOC4mGnEL-9CpoGhMg',
#    'alias': 'mings-caffe-new-york-2',
#    'name': "Ming's Caffe",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vgCU2O31el1_g1bEKxgmLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mings-caffe-new-york-2?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 118,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714321, 'longitude': -73.990509},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '28 Canal St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 Canal St', 'New York, NY 10002']},
#    'phone': '+12129781888',
#    'display_phone': '(212) 978-1888',
#    'distance': 2086.7795942083126},
#   {'id': '__r8_g1cgDaiDn10cGeJ3Q',
#    'alias': 'new-china-red-new-york',
#    'name': 'New China Red',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gsfiiwySR5mWnxx70KA0PQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-china-red-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 33,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.715023, 'longitude': -74.008636},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '118 Chambers St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['118 Chambers St', 'New York, NY 10007']},
#    'phone': '+12122674015',
#    'display_phone': '(212) 267-4015',
#    'distance': 2452.3155188530686},
#   {'id': 'Mx4jHwGh5ZFHRMyiWZ_xfw',
#    'alias': 'happy-express-cafe-new-york-3',
#    'name': 'Happy Express Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TRFxa78dawOYkIIwJ2useg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/happy-express-cafe-new-york-3?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 41,
#    'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7145133, 'longitude': -73.9924451},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '6 Allen St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6 Allen St', 'New York, NY 10002']},
#    'phone': '+12129659898',
#    'display_phone': '(212) 965-9898',
#    'distance': 2099.6082718994458},
#   {'id': 'pmE7JG661llrNWu9IA5Y_Q',
#    'alias': 'tan-wong-restaurant-new-york',
#    'name': 'Tan Wong Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/W9crxVMi9onR-VBrIqo92A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tan-wong-restaurant-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 8,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7136, 'longitude': -73.99317},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '103 E Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 E Broadway', 'New York, NY 10002']},
#    'phone': '+12123856015',
#    'display_phone': '(212) 385-6015',
#    'distance': 1979.27005678312},
#   {'id': 'bT4CDzyhV-frXV6ijvXnvw',
#    'alias': 'super-taste-new-york',
#    'name': 'Super Taste',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Y-rfOV4CDxtWPkV_d2JWcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/super-taste-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 551,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71513, 'longitude': -73.99341},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '26 Eldridge St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 Eldridge St', 'New York, NY 10002']},
#    'phone': '+16462830999',
#    'display_phone': '(646) 283-0999',
#    'distance': 2144.1588420993007},
#   {'id': '2IrDzLVFUFPp229c1x8YNw',
#    'alias': 'hong-man-new-york',
#    'name': 'Hong Man',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UsSOZuq4qGImJqudMtge2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hong-man-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 137,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.715145, 'longitude': -73.993698},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '27 Eldridge St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27 Eldridge St', 'New York, NY 10002']},
#    'phone': '+12129250805',
#    'display_phone': '(212) 925-0805',
#    'distance': 2153.324285475651},
#   {'id': 'd_TC6Om2EBTzHVm_lCgNtg',
#    'alias': 'great-ny-noodle-town-new-york',
#    'name': 'Great NY Noodle Town',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BAzE7G6WNiUqJqLTRPYSvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/great-ny-noodle-town-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 1319,
#    'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7150363828814,
#     'longitude': -73.9971172437072},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '28 Bowery',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 Bowery', 'New York, NY 10013']},
#    'phone': '+12123490923',
#    'display_phone': '(212) 349-0923',
#    'distance': 2151.2285085230733},
#   {'id': 'GfLL6-n6UNZ07SEHfjeIgA',
#    'alias': 'mee-sum-cafe-new-york',
#    'name': 'Mee Sum Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/N4Yc3eeDHXeePQWkeyBnyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mee-sum-cafe-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 33,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.715045, 'longitude': -73.998291},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '26 Pell St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 Pell St', 'New York, NY 10013']},
#    'phone': '+12123495260',
#    'display_phone': '(212) 349-5260',
#    'distance': 2165.8030537026007},
#   {'id': 'lRSiXYB09Z5x1iINqQ7rHA',
#    'alias': 'dim-sum-go-go-new-york',
#    'name': 'Dim Sum Go Go',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Gxye_bydWtbWabHxVDQ5gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dim-sum-go-go-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 781,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7132415735622,
#     'longitude': -73.9977319419107},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '5 E Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 E Broadway', 'New York, NY 10038']},
#    'phone': '+12127320797',
#    'display_phone': '(212) 732-0797',
#    'distance': 1959.724552602302},
#   {'id': 'Y1s36Tk63HIzAc76X_fAiQ',
#    'alias': 'hop-shing-restaurant-new-york',
#    'name': 'Hop Shing Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cYzq0hhv8ruMQ9HinOEVzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hop-shing-restaurant-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 533,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71418, 'longitude': -73.99811},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '9 Chatham Sq',
#     'address2': 'Ste 1',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Chatham Sq', 'Ste 1', 'New York, NY 10038']},
#    'phone': '+12122670220',
#    'display_phone': '(212) 267-0220',
#    'distance': 2043.708843448393},
#   {'id': 'VaL9GaBR_GR-q9d1VzJF3g',
#    'alias': 'suteishi-new-york',
#    'name': 'Suteishi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4BbRNhy7IJz7PL1sJDmAlg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/suteishi-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 490,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70788, 'longitude': -74.00194},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '24 Peck Slip',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 Peck Slip', 'New York, NY 10038']},
#    'phone': '+12127662344',
#    'display_phone': '(212) 766-2344',
#    'distance': 1487.0761321951231},
#   {'id': 'wctR1TrheHAwpHZ2sJknEw',
#    'alias': 'yemen-cafe-and-restaurant-brooklyn-3',
#    'name': 'Yemen Cafe & Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/naw33McdBGb70-6qc5go4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yemen-cafe-and-restaurant-brooklyn-3?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 510,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6899167976363,
#     'longitude': -73.9936561765076},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '176 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['176 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17188349533',
#    'display_phone': '(718) 834-9533',
#    'distance': 657.1890288804198},
#   {'id': 'HFOiW4RvijuoblE4DD3JwA',
#    'alias': 'dekalb-market-hall-brooklyn-2',
#    'name': 'Dekalb Market Hall',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p3HJcEcHV7KuX0XVh30KUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dekalb-market-hall-brooklyn-2?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 665,
#    'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.691025, 'longitude': -73.983311},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '445 Albee Square W',
#     'address2': 'Basement Level',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['445 Albee Square W',
#      'Basement Level',
#      'Brooklyn, NY 11201']},
#    'phone': '+19293596555',
#    'display_phone': '(929) 359-6555',
#    'distance': 1073.7041848440692},
#   {'id': 'rkeH5HJIuX7ZcOaYNum9xA',
#    'alias': 'wus-wonton-king-new-york',
#    'name': "Wu's Wonton King",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QjIkktkArC8ZLduMobSAzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wus-wonton-king-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 265,
#    'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7139415501646,
#     'longitude': -73.9899386554248},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '165 E Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['165 E Broadway', 'New York, NY 10002']},
#    'phone': '+12124771111',
#    'display_phone': '(212) 477-1111',
#    'distance': 2051.5053402356925},
#   {'id': 'Cd11Q5nxqthvg5xQx2SW2g',
#    'alias': 'tasty-dumpling-new-york',
#    'name': 'Tasty Dumpling',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/l6Rh7VbXaavoXZ2z4Xr0CQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tasty-dumpling-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 500,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7149408310765,
#     'longitude': -73.9995409548283},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '42 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 Mulberry St', 'New York, NY 10013']},
#    'phone': '+12123490070',
#    'display_phone': '(212) 349-0070',
#    'distance': 2172.2108661811985},
#   {'id': 'ZyQfNryF0YBdzGnzLoVsWQ',
#    'alias': 'j-j-noodle-restaurant-new-york',
#    'name': 'J.J. Noodle Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/10oc8taJq51elsEX_HURjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/j-j-noodle-restaurant-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 45,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7128724455833,
#     'longitude': -73.9968185126781},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '19 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Henry St', 'New York, NY 10002']},
#    'phone': '+12125712440',
#    'display_phone': '(212) 571-2440',
#    'distance': 1905.5049326686446},
#   {'id': '_5E5cZP0PzkwfdEqTebBUg',
#    'alias': 'lanzhou-ramen-new-york-3',
#    'name': 'Lanzhou Ramen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IpPighKcuYrTyeoFl6jKFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lanzhou-ramen-new-york-3?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 57,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7136041, 'longitude': -73.9930138},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '107 E Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['107 E Broadway', 'New York, NY 10038']},
#    'phone': '+16469983175',
#    'display_phone': '(646) 998-3175',
#    'distance': 1982.8902576294413},
#   {'id': 'bNO0801dOoSSFJuDdTDzYQ',
#    'alias': 'hadramout-restaurant-brooklyn',
#    'name': 'Hadramout Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BU1YCbgdFtGe2XggJMK3kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hadramout-restaurant-brooklyn?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 80,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6898184, 'longitude': -73.9938774},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '172 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['172 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17182221066',
#    'display_phone': '(718) 222-1066',
#    'distance': 666.6413242254652},
#   {'id': '02zyTkuXvbGcbA9en_20Gw',
#    'alias': 'chatham-seafood-restaurant-new-york-3',
#    'name': 'Chatham Seafood Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9vyr6zN3TkiZgnOeye7XhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chatham-seafood-restaurant-new-york-3?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 199,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7139257701126,
#     'longitude': -73.9982688968362},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '6 Chatham Sq',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6 Chatham Sq', 'New York, NY 10038']},
#    'phone': '+12122338877',
#    'display_phone': '(212) 233-8877',
#    'distance': 2041.8158664868913},
#   {'id': 'cn3JXMq29UfRkFCUD0Bhbw',
#    'alias': 'fried-dumpling-new-york',
#    'name': 'Fried Dumpling',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bHZRArfOJlXzwRtky_Fn_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fried-dumpling-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 518,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7145984, 'longitude': -73.9993465},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '106 Mosco St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['106 Mosco St', 'New York, NY 10013']},
#    'phone': '+12126931060',
#    'display_phone': '(212) 693-1060',
#    'distance': 2127.405749442871},
#   {'id': 'NL7yHrgnOVNtKNRPon5vGQ',
#    'alias': 'delight-28-restaurant-new-york-2',
#    'name': 'Delight 28 Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KXhoDiZyz2-GbzBzVD2NMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/delight-28-restaurant-new-york-2?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 162,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.715089, 'longitude': -73.998459},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '28 Pell St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 Pell St', 'New York, NY 10013']},
#    'phone': '+12122858686',
#    'display_phone': '(212) 285-8686',
#    'distance': 2172.060818671315},
#   {'id': 'aoYDuvipcT_XGAM5ckFJnA',
#    'alias': 'cafe-water-new-york',
#    'name': 'Cafe Water',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YfwkAImpiK3ClwXhZgbn-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-water-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 86,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7056344, 'longitude': -74.0068667},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '130 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['130 Water St', 'New York, NY 10005']},
#    'phone': '+12127851320',
#    'display_phone': '(212) 785-1320',
#    'distance': 1517.7687908353644},
#   {'id': '7YxyC11C6gTKGg2qoiF4XQ',
#    'alias': 'banh-mi-cart-new-york',
#    'name': 'Banh Mi Cart',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T9hX8NRQa68Gupz4CrnXUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/banh-mi-cart-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 123,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70455, 'longitude': -74.0094699},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': 'Pearl St & Hanover Sq',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Pearl St & Hanover Sq', 'New York, NY 10038']},
#    'phone': '+19174957071',
#    'display_phone': '(917) 495-7071',
#    'distance': 1602.5262183452712},
#   {'id': '-qO9s7w4krZ_Wfziqzn7Hw',
#    'alias': 'adels-halal-food-new-york-2',
#    'name': "Adel's Halal Food",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F1TKk-94tFi7g3BnUGiGBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/adels-halal-food-new-york-2?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 75,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70578, 'longitude': -74.00554},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': 'Maiden Ln & Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Maiden Ln & Front St', 'New York, NY 10038']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1452.8566219302647},
#   {'id': 'GlPJPpKvPR4d8dmcSEYpdA',
#    'alias': 'takahachi-bakery-new-york',
#    'name': 'Takahachi Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aoi0dkVvxooH8ZCFUC3lSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/takahachi-bakery-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 899,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71393, 'longitude': -74.00822},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '25 Murray St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Murray St', 'New York, NY 10007']},
#    'phone': '+12127915550',
#    'display_phone': '(212) 791-5550',
#    'distance': 2333.1659440405356},
#   {'id': 'brs8l_uwP8lKNzvbJD5kiA',
#    'alias': 'cafe-exchange-new-york',
#    'name': 'Cafe Exchange',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QrcqGznOWd6_tMPeAV57Ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-exchange-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 81,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.70673, 'longitude': -74.01312},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '49 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10006',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['49 Broadway', 'New York, NY 10006']},
#    'phone': '+12124255000',
#    'display_phone': '(212) 425-5000',
#    'distance': 2012.9357279020985},
#   {'id': 'tAHRDrCR0l_utA91IyOYNw',
#    'alias': 'baba-ghanouge-new-york',
#    'name': 'Baba Ghanouge',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Wv-zUukAA_vHJ7vgVSkY3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baba-ghanouge-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 151,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.71511, 'longitude': -74.00758},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '165 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['165 Church St', 'New York, NY 10007']},
#    'phone': '+12125712020',
#    'display_phone': '(212) 571-2020',
#    'distance': 2414.1235615722085}],
#  'total': 30,
#  'region': {'center': {'longitude': -73.9943790435791,
#    'latitude': 40.69580157862677}}}

# %% [markdown]
# Using one of the methods above load the response data and assign it to a variable `data`.

# %%
data = response.json()

# %%
data
# Out:
# {'businesses': [{'id': 'rPTX2J5KGDkN1QhPD-QOvg',
#    'alias': 'xifu-food-brooklyn',
#    'name': 'Xifu Food',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SiWrJqq1wyIbUWFbhjgoXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xifu-food-brooklyn?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 139,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6880326, 'longitude': -73.9819963},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '318 Livingston St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['318 Livingston St', 'Brooklyn, NY 11217']},
#    'phone': '+17182378886',
#    'display_phone': '(718) 237-8886',
#    'distance': 1356.6514866975099},
#   {'id': '5u4T6-Z-KhHrRZ9g54pugQ',
#    'alias': 'carols-bun-new-york-3',
#    'name': "Carol's Bun",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/d8qaSRuicMeA-HCl7MzoqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carols-bun-new-york-3?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 32,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7138317002555,
#     'longitude': -73.9914554524045},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '139 E Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 E Broadway', 'New York, NY 10002']},
#    'phone': '+12125660203',
#    'display_phone': '(212) 566-0203',
#    'distance': 2019.9457609230337},
#   {'id': 'nrPfcOC4mGnEL-9CpoGhMg',
#    'alias': 'mings-caffe-new-york-2',
#    'name': "Ming's Caffe",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vgCU2O31el1_g1bEKxgmLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mings-caffe-new-york-2?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 118,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714321, 'longitude': -73.990509},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '28 Canal St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 Canal St', 'New York, NY 10002']},
#    'phone': '+12129781888',
#    'display_phone': '(212) 978-1888',
#    'distance': 2086.7795942083126},
#   {'id': '__r8_g1cgDaiDn10cGeJ3Q',
#    'alias': 'new-china-red-new-york',
#    'name': 'New China Red',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gsfiiwySR5mWnxx70KA0PQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-china-red-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 33,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.715023, 'longitude': -74.008636},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '118 Chambers St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['118 Chambers St', 'New York, NY 10007']},
#    'phone': '+12122674015',
#    'display_phone': '(212) 267-4015',
#    'distance': 2452.3155188530686},
#   {'id': 'Mx4jHwGh5ZFHRMyiWZ_xfw',
#    'alias': 'happy-express-cafe-new-york-3',
#    'name': 'Happy Express Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TRFxa78dawOYkIIwJ2useg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/happy-express-cafe-new-york-3?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 41,
#    'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7145133, 'longitude': -73.9924451},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '6 Allen St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6 Allen St', 'New York, NY 10002']},
#    'phone': '+12129659898',
#    'display_phone': '(212) 965-9898',
#    'distance': 2099.6082718994458},
#   {'id': 'pmE7JG661llrNWu9IA5Y_Q',
#    'alias': 'tan-wong-restaurant-new-york',
#    'name': 'Tan Wong Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/W9crxVMi9onR-VBrIqo92A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tan-wong-restaurant-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 8,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7136, 'longitude': -73.99317},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '103 E Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 E Broadway', 'New York, NY 10002']},
#    'phone': '+12123856015',
#    'display_phone': '(212) 385-6015',
#    'distance': 1979.27005678312},
#   {'id': 'bT4CDzyhV-frXV6ijvXnvw',
#    'alias': 'super-taste-new-york',
#    'name': 'Super Taste',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Y-rfOV4CDxtWPkV_d2JWcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/super-taste-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 551,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71513, 'longitude': -73.99341},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '26 Eldridge St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 Eldridge St', 'New York, NY 10002']},
#    'phone': '+16462830999',
#    'display_phone': '(646) 283-0999',
#    'distance': 2144.1588420993007},
#   {'id': '2IrDzLVFUFPp229c1x8YNw',
#    'alias': 'hong-man-new-york',
#    'name': 'Hong Man',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UsSOZuq4qGImJqudMtge2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hong-man-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 137,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.715145, 'longitude': -73.993698},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '27 Eldridge St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27 Eldridge St', 'New York, NY 10002']},
#    'phone': '+12129250805',
#    'display_phone': '(212) 925-0805',
#    'distance': 2153.324285475651},
#   {'id': 'd_TC6Om2EBTzHVm_lCgNtg',
#    'alias': 'great-ny-noodle-town-new-york',
#    'name': 'Great NY Noodle Town',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BAzE7G6WNiUqJqLTRPYSvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/great-ny-noodle-town-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 1319,
#    'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7150363828814,
#     'longitude': -73.9971172437072},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '28 Bowery',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 Bowery', 'New York, NY 10013']},
#    'phone': '+12123490923',
#    'display_phone': '(212) 349-0923',
#    'distance': 2151.2285085230733},
#   {'id': 'GfLL6-n6UNZ07SEHfjeIgA',
#    'alias': 'mee-sum-cafe-new-york',
#    'name': 'Mee Sum Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/N4Yc3eeDHXeePQWkeyBnyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mee-sum-cafe-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 33,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.715045, 'longitude': -73.998291},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '26 Pell St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 Pell St', 'New York, NY 10013']},
#    'phone': '+12123495260',
#    'display_phone': '(212) 349-5260',
#    'distance': 2165.8030537026007},
#   {'id': 'lRSiXYB09Z5x1iINqQ7rHA',
#    'alias': 'dim-sum-go-go-new-york',
#    'name': 'Dim Sum Go Go',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Gxye_bydWtbWabHxVDQ5gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dim-sum-go-go-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 781,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7132415735622,
#     'longitude': -73.9977319419107},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '5 E Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 E Broadway', 'New York, NY 10038']},
#    'phone': '+12127320797',
#    'display_phone': '(212) 732-0797',
#    'distance': 1959.724552602302},
#   {'id': 'Y1s36Tk63HIzAc76X_fAiQ',
#    'alias': 'hop-shing-restaurant-new-york',
#    'name': 'Hop Shing Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cYzq0hhv8ruMQ9HinOEVzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hop-shing-restaurant-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 533,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71418, 'longitude': -73.99811},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '9 Chatham Sq',
#     'address2': 'Ste 1',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Chatham Sq', 'Ste 1', 'New York, NY 10038']},
#    'phone': '+12122670220',
#    'display_phone': '(212) 267-0220',
#    'distance': 2043.708843448393},
#   {'id': 'VaL9GaBR_GR-q9d1VzJF3g',
#    'alias': 'suteishi-new-york',
#    'name': 'Suteishi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4BbRNhy7IJz7PL1sJDmAlg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/suteishi-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 490,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70788, 'longitude': -74.00194},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '24 Peck Slip',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 Peck Slip', 'New York, NY 10038']},
#    'phone': '+12127662344',
#    'display_phone': '(212) 766-2344',
#    'distance': 1487.0761321951231},
#   {'id': 'wctR1TrheHAwpHZ2sJknEw',
#    'alias': 'yemen-cafe-and-restaurant-brooklyn-3',
#    'name': 'Yemen Cafe & Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/naw33McdBGb70-6qc5go4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yemen-cafe-and-restaurant-brooklyn-3?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 510,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6899167976363,
#     'longitude': -73.9936561765076},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '176 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['176 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17188349533',
#    'display_phone': '(718) 834-9533',
#    'distance': 657.1890288804198},
#   {'id': 'HFOiW4RvijuoblE4DD3JwA',
#    'alias': 'dekalb-market-hall-brooklyn-2',
#    'name': 'Dekalb Market Hall',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p3HJcEcHV7KuX0XVh30KUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dekalb-market-hall-brooklyn-2?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 665,
#    'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.691025, 'longitude': -73.983311},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '445 Albee Square W',
#     'address2': 'Basement Level',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['445 Albee Square W',
#      'Basement Level',
#      'Brooklyn, NY 11201']},
#    'phone': '+19293596555',
#    'display_phone': '(929) 359-6555',
#    'distance': 1073.7041848440692},
#   {'id': 'rkeH5HJIuX7ZcOaYNum9xA',
#    'alias': 'wus-wonton-king-new-york',
#    'name': "Wu's Wonton King",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QjIkktkArC8ZLduMobSAzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wus-wonton-king-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 265,
#    'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7139415501646,
#     'longitude': -73.9899386554248},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '165 E Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['165 E Broadway', 'New York, NY 10002']},
#    'phone': '+12124771111',
#    'display_phone': '(212) 477-1111',
#    'distance': 2051.5053402356925},
#   {'id': 'Cd11Q5nxqthvg5xQx2SW2g',
#    'alias': 'tasty-dumpling-new-york',
#    'name': 'Tasty Dumpling',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/l6Rh7VbXaavoXZ2z4Xr0CQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tasty-dumpling-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 500,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7149408310765,
#     'longitude': -73.9995409548283},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '42 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 Mulberry St', 'New York, NY 10013']},
#    'phone': '+12123490070',
#    'display_phone': '(212) 349-0070',
#    'distance': 2172.2108661811985},
#   {'id': 'ZyQfNryF0YBdzGnzLoVsWQ',
#    'alias': 'j-j-noodle-restaurant-new-york',
#    'name': 'J.J. Noodle Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/10oc8taJq51elsEX_HURjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/j-j-noodle-restaurant-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 45,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7128724455833,
#     'longitude': -73.9968185126781},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '19 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Henry St', 'New York, NY 10002']},
#    'phone': '+12125712440',
#    'display_phone': '(212) 571-2440',
#    'distance': 1905.5049326686446},
#   {'id': '_5E5cZP0PzkwfdEqTebBUg',
#    'alias': 'lanzhou-ramen-new-york-3',
#    'name': 'Lanzhou Ramen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IpPighKcuYrTyeoFl6jKFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lanzhou-ramen-new-york-3?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 57,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7136041, 'longitude': -73.9930138},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '107 E Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['107 E Broadway', 'New York, NY 10038']},
#    'phone': '+16469983175',
#    'display_phone': '(646) 998-3175',
#    'distance': 1982.8902576294413},
#   {'id': 'bNO0801dOoSSFJuDdTDzYQ',
#    'alias': 'hadramout-restaurant-brooklyn',
#    'name': 'Hadramout Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BU1YCbgdFtGe2XggJMK3kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hadramout-restaurant-brooklyn?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 80,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6898184, 'longitude': -73.9938774},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '172 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['172 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17182221066',
#    'display_phone': '(718) 222-1066',
#    'distance': 666.6413242254652},
#   {'id': '02zyTkuXvbGcbA9en_20Gw',
#    'alias': 'chatham-seafood-restaurant-new-york-3',
#    'name': 'Chatham Seafood Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9vyr6zN3TkiZgnOeye7XhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chatham-seafood-restaurant-new-york-3?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 199,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7139257701126,
#     'longitude': -73.9982688968362},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '6 Chatham Sq',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6 Chatham Sq', 'New York, NY 10038']},
#    'phone': '+12122338877',
#    'display_phone': '(212) 233-8877',
#    'distance': 2041.8158664868913},
#   {'id': 'cn3JXMq29UfRkFCUD0Bhbw',
#    'alias': 'fried-dumpling-new-york',
#    'name': 'Fried Dumpling',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bHZRArfOJlXzwRtky_Fn_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fried-dumpling-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 518,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7145984, 'longitude': -73.9993465},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '106 Mosco St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['106 Mosco St', 'New York, NY 10013']},
#    'phone': '+12126931060',
#    'display_phone': '(212) 693-1060',
#    'distance': 2127.405749442871},
#   {'id': 'NL7yHrgnOVNtKNRPon5vGQ',
#    'alias': 'delight-28-restaurant-new-york-2',
#    'name': 'Delight 28 Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KXhoDiZyz2-GbzBzVD2NMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/delight-28-restaurant-new-york-2?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 162,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.715089, 'longitude': -73.998459},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '28 Pell St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 Pell St', 'New York, NY 10013']},
#    'phone': '+12122858686',
#    'display_phone': '(212) 285-8686',
#    'distance': 2172.060818671315},
#   {'id': 'aoYDuvipcT_XGAM5ckFJnA',
#    'alias': 'cafe-water-new-york',
#    'name': 'Cafe Water',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YfwkAImpiK3ClwXhZgbn-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-water-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 86,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7056344, 'longitude': -74.0068667},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '130 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['130 Water St', 'New York, NY 10005']},
#    'phone': '+12127851320',
#    'display_phone': '(212) 785-1320',
#    'distance': 1517.7687908353644},
#   {'id': '7YxyC11C6gTKGg2qoiF4XQ',
#    'alias': 'banh-mi-cart-new-york',
#    'name': 'Banh Mi Cart',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T9hX8NRQa68Gupz4CrnXUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/banh-mi-cart-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 123,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70455, 'longitude': -74.0094699},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': 'Pearl St & Hanover Sq',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Pearl St & Hanover Sq', 'New York, NY 10038']},
#    'phone': '+19174957071',
#    'display_phone': '(917) 495-7071',
#    'distance': 1602.5262183452712},
#   {'id': '-qO9s7w4krZ_Wfziqzn7Hw',
#    'alias': 'adels-halal-food-new-york-2',
#    'name': "Adel's Halal Food",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F1TKk-94tFi7g3BnUGiGBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/adels-halal-food-new-york-2?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 75,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70578, 'longitude': -74.00554},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': 'Maiden Ln & Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Maiden Ln & Front St', 'New York, NY 10038']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1452.8566219302647},
#   {'id': 'GlPJPpKvPR4d8dmcSEYpdA',
#    'alias': 'takahachi-bakery-new-york',
#    'name': 'Takahachi Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aoi0dkVvxooH8ZCFUC3lSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/takahachi-bakery-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 899,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71393, 'longitude': -74.00822},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '25 Murray St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Murray St', 'New York, NY 10007']},
#    'phone': '+12127915550',
#    'display_phone': '(212) 791-5550',
#    'distance': 2333.1659440405356},
#   {'id': 'brs8l_uwP8lKNzvbJD5kiA',
#    'alias': 'cafe-exchange-new-york',
#    'name': 'Cafe Exchange',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QrcqGznOWd6_tMPeAV57Ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-exchange-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 81,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.70673, 'longitude': -74.01312},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '49 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10006',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['49 Broadway', 'New York, NY 10006']},
#    'phone': '+12124255000',
#    'display_phone': '(212) 425-5000',
#    'distance': 2012.9357279020985},
#   {'id': 'tAHRDrCR0l_utA91IyOYNw',
#    'alias': 'baba-ghanouge-new-york',
#    'name': 'Baba Ghanouge',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Wv-zUukAA_vHJ7vgVSkY3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baba-ghanouge-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#    'review_count': 151,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.71511, 'longitude': -74.00758},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '165 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['165 Church St', 'New York, NY 10007']},
#    'phone': '+12125712020',
#    'display_phone': '(212) 571-2020',
#    'distance': 2414.1235615722085}],
#  'total': 30,
#  'region': {'center': {'longitude': -73.9943790435791,
#    'latitude': 40.69580157862677}}}

# %%
What are the keys in this dictionary and the datatypes of their values.

# %%
# your code here
# for key in data:
#     print(f'{key}\n {type(data[key])}')
    
for key in data:
    print(key)
    print(type(data[key]))

# data.keys()
# type(data.keys())
# Out:
# businesses
# <class 'list'>
# total
# <class 'int'>
# region
# <class 'dict'>

# %% [markdown]
# How many results did our query return?

# %%
print(len(data['businesses']))
# Out:
# 29

# %% [markdown]
# How many businesses were returned from the API call?

# %%
____
# Out:
# 20

# %% [markdown]
# ### Parsing the Results
#
# There are a lot of key-value pairs for each business. Many of which we do not care about. Let's create a simple parser of this data that will return a list with the name, display_address, and one other data point of your choice. First we want to assign one of the businesses to the `business` variable. Once we cna properly parse oonne business  we can use a loop to do them all.

# %%
business = data['businesses'][6]

# %%
business
# Out:
# {'id': 'bT4CDzyhV-frXV6ijvXnvw',
#  'alias': 'super-taste-new-york',
#  'name': 'Super Taste',
#  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Y-rfOV4CDxtWPkV_d2JWcg/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/super-taste-new-york?adjust_creative=M3mNq5Ck5s1JoAhGyL5EQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=M3mNq5Ck5s1JoAhGyL5EQg',
#  'review_count': 551,
#  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#   {'alias': 'noodles', 'title': 'Noodles'}],
#  'rating': 4.0,
#  'coordinates': {'latitude': 40.71513, 'longitude': -73.99341},
#  'transactions': [],
#  'price': '$',
#  'location': {'address1': '26 Eldridge St',
#   'address2': None,
#   'address3': '',
#   'city': 'New York',
#   'zip_code': '10002',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['26 Eldridge St', 'New York, NY 10002']},
#  'phone': '+16462830999',
#  'display_phone': '(646) 283-0999',
#  'distance': 2144.1588420993007}

# %%
business

# %% [markdown]
# Rember we want the following pieces of information:
# name, display_address, and one other data point of your choice

# %%
biz_list = [business['name'], 
            ', '.join(business['location']['display_address']), 
            business['display_phone']]

# %%
biz_list
# Out:
# ['Super Taste', '26 Eldridge St, New York, NY 10002', '(646) 283-0999']

# %% [markdown]
# Now that we know how to do this for one business. Let create a function that recieves the list of businesses and returns a list of tuples with the important information.

# %%
def parse_data(list_of_data):
    # create a container to hold our parsed data
    parsed_data = []
    
    # loop through our business and parse each individual business
    for business in list_of_data:
        print(business['name'])
        biz_list = [business['name'], 
            ', '.join(business['location']['display_address']), 
            business['display_phone']]
    # in the loop, add each individual parsed  business to our data container
        parsed_data.append(biz_list)

    # return the container with all of the parsed results
    return parsed_data

# %%
parsed_data = parse_data(data['businesses'])
parsed_data
# Out:
# Xifu Food
# Carol's Bun
# Ming's Caffe
# New China Red
# Happy Express Cafe
# Tan Wong Restaurant
# Super Taste
# Hong Man
# Great NY Noodle Town
# Mee Sum Cafe
# Dim Sum Go Go
# Hop Shing Restaurant
# Suteishi
# Yemen Cafe & Restaurant
# Dekalb Market Hall
# Wu's Wonton King
# Tasty Dumpling
# J.J. Noodle Restaurant
# Lanzhou Ramen
# Hadramout Restaurant
# Chatham Seafood Restaurant
# Fried Dumpling
# Delight 28 Restaurant
# Cafe Water
# Banh Mi Cart
# Adel's Halal Food
# Takahachi Bakery
# Cafe Exchange
# Baba Ghanouge
# [['Xifu Food', '318 Livingston St, Brooklyn, NY 11217', '(718) 237-8886'],
#  ["Carol's Bun", '139 E Broadway, New York, NY 10002', '(212) 566-0203'],
#  ["Ming's Caffe", '28 Canal St, New York, NY 10002', '(212) 978-1888'],
#  ['New China Red', '118 Chambers St, New York, NY 10007', '(212) 267-4015'],
#  ['Happy Express Cafe', '6 Allen St, New York, NY 10002', '(212) 965-9898'],
#  ['Tan Wong Restaurant',
#   '103 E Broadway, New York, NY 10002',
#   '(212) 385-6015'],
#  ['Super Taste', '26 Eldridge St, New York, NY 10002', '(646) 283-0999'],
#  ['Hong Man', '27 Eldridge St, New York, NY 10002', '(212) 925-0805'],
#  ['Great NY Noodle Town', '28 Bowery, New York, NY 10013', '(212) 349-0923'],
#  ['Mee Sum Cafe', '26 Pell St, New York, NY 10013', '(212) 349-5260'],
#  ['Dim Sum Go Go', '5 E Broadway, New York, NY 10038', '(212) 732-0797'],
#  ['Hop Shing Restaurant',
#   '9 Chatham Sq, Ste 1, New York, NY 10038',
#   '(212) 267-0220'],
#  ['Suteishi', '24 Peck Slip, New York, NY 10038', '(212) 766-2344'],
#  ['Yemen Cafe & Restaurant',
#   '176 Atlantic Ave, Brooklyn, NY 11201',
#   '(718) 834-9533'],
#  ['Dekalb Market Hall',
#   '445 Albee Square W, Basement Level, Brooklyn, NY 11201',
#   '(929) 359-6555'],
#  ["Wu's Wonton King", '165 E Broadway, New York, NY 10002', '(212) 477-1111'],
#  ['Tasty Dumpling', '42 Mulberry St, New York, NY 10013', '(212) 349-0070'],
#  ['J.J. Noodle Restaurant',
#   '19 Henry St, New York, NY 10002',
#   '(212) 571-2440'],
#  ['Lanzhou Ramen', '107 E Broadway, New York, NY 10038', '(646) 998-3175'],
#  ['Hadramout Restaurant',
#   '172 Atlantic Ave, Brooklyn, NY 11201',
#   '(718) 222-1066'],
#  ['Chatham Seafood Restaurant',
#   '6 Chatham Sq, New York, NY 10038',
#   '(212) 233-8877'],
#  ['Fried Dumpling', '106 Mosco St, New York, NY 10013', '(212) 693-1060'],
#  ['Delight 28 Restaurant', '28 Pell St, New York, NY 10013', '(212) 285-8686'],
#  ['Cafe Water', '130 Water St, New York, NY 10005', '(212) 785-1320'],
#  ['Banh Mi Cart',
#   'Pearl St & Hanover Sq, New York, NY 10038',
#   '(917) 495-7071'],
#  ["Adel's Halal Food", 'Maiden Ln & Front St, New York, NY 10038', ''],
#  ['Takahachi Bakery', '25 Murray St, New York, NY 10007', '(212) 791-5550'],
#  ['Cafe Exchange', '49 Broadway, New York, NY 10006', '(212) 425-5000'],
#  ['Baba Ghanouge', '165 Church St, New York, NY 10007', '(212) 571-2020']]

# %%
import pandas as pd

# %%
pd.DataFrame(parsed_data)
# Out:
#                              0  \
# 0                    Xifu Food
# 1                  Carol's Bun
# 2                 Ming's Caffe
# 3                New China Red
# 4           Happy Express Cafe
# 5          Tan Wong Restaurant
# 6                  Super Taste
# 7                     Hong Man
# 8         Great NY Noodle Town
# 9                 Mee Sum Cafe
# 10               Dim Sum Go Go
# 11        Hop Shing Restaurant
# 12                    Suteishi
# 13     Yemen Cafe & Restaurant
# 14          Dekalb Market Hall
# 15            Wu's Wonton King
# 16              Tasty Dumpling
# 17      J.J. Noodle Restaurant
# 18               Lanzhou Ramen
# 19        Hadramout Restaurant
# 20  Chatham Seafood Restaurant
# 21              Fried Dumpling
# 22       Delight 28 Restaurant
# 23                  Cafe Water
# 24                Banh Mi Cart
# 25           Adel's Halal Food
# 26            Takahachi Bakery
# 27               Cafe Exchange
# 28               Baba Ghanouge
#
#                                                     1               2
# 0               318 Livingston St, Brooklyn, NY 11217  (718) 237-8886
# 1                  139 E Broadway, New York, NY 10002  (212) 566-0203
# 2                     28 Canal St, New York, NY 10002  (212) 978-1888
# 3                 118 Chambers St, New York, NY 10007  (212) 267-4015
# 4                      6 Allen St, New York, NY 10002  (212) 965-9898
# 5                  103 E Broadway, New York, NY 10002  (212) 385-6015
# 6                  26 Eldridge St, New York, NY 10002  (646) 283-0999
# 7                  27 Eldridge St, New York, NY 10002  (212) 925-0805
# 8                       28 Bowery, New York, NY 10013  (212) 349-0923
# 9                      26 Pell St, New York, NY 10013  (212) 349-5260
# 10                   5 E Broadway, New York, NY 10038  (212) 732-0797
# 11            9 Chatham Sq, Ste 1, New York, NY 10038  (212) 267-0220
# 12                   24 Peck Slip, New York, NY 10038  (212) 766-2344
# 13               176 Atlantic Ave, Brooklyn, NY 11201  (718) 834-9533
# 14  445 Albee Square W, Basement Level, Brooklyn, ...  (929) 359-6555
# 15                 165 E Broadway, New York, NY 10002  (212) 477-1111
# 16                 42 Mulberry St, New York, NY 10013  (212) 349-0070
# 17                    19 Henry St, New York, NY 10002  (212) 571-2440
# 18                 107 E Broadway, New York, NY 10038  (646) 998-3175
# 19               172 Atlantic Ave, Brooklyn, NY 11201  (718) 222-1066
# 20                   6 Chatham Sq, New York, NY 10038  (212) 233-8877
# 21                   106 Mosco St, New York, NY 10013  (212) 693-1060
# 22                     28 Pell St, New York, NY 10013  (212) 285-8686
# 23                   130 Water St, New York, NY 10005  (212) 785-1320
# 24          Pearl St & Hanover Sq, New York, NY 10038  (917) 495-7071
# 25           Maiden Ln & Front St, New York, NY 10038
# 26                   25 Murray St, New York, NY 10007  (212) 791-5550
# 27                    49 Broadway, New York, NY 10006  (212) 425-5000
# 28                  165 Church St, New York, NY 10007  (212) 571-2020

# %%
columns = ['Name', 'Address', 'Phone']

# %%
df = pd.DataFrame(parsed_data, columns = columns)

# %%
# df.to_csv('yelp_data.csv')
# ^^ code if we want to save the df as a csv
